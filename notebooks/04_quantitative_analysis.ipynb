# %%
"""
``autoreload`` is an IPython extension that reloads modules
automatically before executing the line of code typed.
"""

# %load_ext autoreload
# %autoreload 2

# %%
qs.extend_pandas()

# %%
df = pd.read_csv('../data/02_processed/AAPL_processed.csv')
df[['Date','Returns']]
# Out:
#              Date   Returns
# 0      1981-02-24 -0.035531
# 1      1981-02-25  0.063154
# 2      1981-02-26  0.014850
# 3      1981-02-27  0.034153
# 4      1981-03-02  0.004717
# ...           ...       ...
# 11020  2024-11-08 -0.001188
# 11021  2024-11-11 -0.012029
# 11022  2024-11-12  0.000000
# 11023  2024-11-13  0.003969
# 11024  2024-11-14  0.013770
#
# [11025 rows x 2 columns]

# %%
stock = qs.utils.download_returns('AAPL')
stock
# Out:
# Date
# 1980-12-12         NaN
# 1980-12-15   -0.052171
# 1980-12-16   -0.073398
# 1980-12-17    0.024751
# 1980-12-18    0.028992
#                 ...
# 2024-11-22    0.005908
# 2024-11-25    0.013051
# 2024-11-26    0.009404
# 2024-11-27   -0.000553
# 2024-11-29    0.010216
# Name: Close, Length: 11084, dtype: float64

# %%
# stock['1981-02-24':]

# %%
inp = df[['Date','Returns']].set_index('Date')
inp.index = pd.to_datetime(inp.index)

# %%
inp.isna().sum()
# Out:
# Returns    0
# dtype: int64

# %%
# %matplotlib inline
import quantstats as qs

# extend pandas functionality with metrics, etc.
qs.extend_pandas()

# fetch the daily returns for a stock
stock = qs.utils.download_returns('META')

# show sharpe ratio
qs.stats.sharpe(stock)

# or using extend_pandas() :)
stock.sharpe()
# Out:
# 0.7426911018215927

# %%
qs.plots.snapshot(stock, title='Facebook Performance', show=True)

# can also be called via:
# stock.plot_snapshot(title='Facebook Performance', show=True)

# %%
qs.reports.html(stock, "SPY")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Miniconda\envs\quant-dev\lib\site-packages\pandas\_libs\tslibs\offsets.pyx:4089, in pandas._libs.tslibs.offsets._get_offset()
#
# KeyError: 'ME'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# File d:\Miniconda\envs\quant-dev\lib\site-packages\pandas\_libs\tslibs\offsets.pyx:4190, in pandas._libs.tslibs.offsets.to_offset()
#
# File d:\Miniconda\envs\quant-dev\lib\site-packages\pandas\_libs\tslibs\offsets.pyx:4095, in pandas._libs.tslibs.offsets._get_offset()
#
# ValueError: Invalid frequency: ME
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 qs.reports.html(stock, "SPY")
#
# File d:\Miniconda\envs\quant-dev\lib\site-packages\quantstats\reports.py:124, in html(returns, benchmark, rf, grayscale, title, output, compounded, periods_per_year, download_filename, figfmt, template_path, match_dates, **kwargs)
#     121 elif isinstance(returns, _pd.DataFrame):
#     122     returns.columns = strategy_title
# --> 124 mtrx = metrics(
#     125     returns=returns,
#     126     benchmark=benchmark,
#     127     rf=rf,
#     128     display=False,
#     129     mode="full",
#     130     sep=True,
#     131     internal="True",
#     132     compounded=compounded,
#     133     periods_per_year=periods_per_year,
#     134     prepare_returns=False,
#     135     benchmark_title=benchmark_title,
#     136     strategy_title=strategy_title,
#     137 )[2:]
#     139 mtrx.index.name = "Metric"
#     140 tpl = tpl.replace("{{metrics}}", _html_table(mtrx))
#
# File d:\Miniconda\envs\quant-dev\lib\site-packages\quantstats\reports.py:960, in metrics(returns, benchmark, rf, display, mode, sep, compounded, periods_per_year, prepare_returns, match_dates, **kwargs)
#     957     metrics["Max Consecutive Losses *int"] = _stats.consecutive_losses(df)
#     959 metrics["Gain/Pain Ratio"] = _stats.gain_to_pain_ratio(df, rf)
# --> 960 metrics["Gain/Pain (1M)"] = _stats.gain_to_pain_ratio(df, rf, "ME")
#     961 # if mode.lower() == 'full':
#     962 #     metrics['GPR (3M)'] = _stats.gain_to_pain_ratio(df, rf, "QE")
#     963 #     metrics['GPR (6M)'] = _stats.gain_to_pain_ratio(df, rf, "2Q")
#     964 #     metrics['GPR (1Y)'] = _stats.gain_to_pain_ratio(df, rf, "YE")
#     965 metrics["~~~~~~~"] = blank
#
# File d:\Miniconda\envs\quant-dev\lib\site-packages\quantstats\stats.py:505, in gain_to_pain_ratio(returns, rf, resolution)
#     500 def gain_to_pain_ratio(returns, rf=0, resolution="D"):
#     501     """
#     502     Jack Schwager's GPR. See here for more info:
#     503     https://archive.is/wip/2rwFW
#     504     """
# --> 505     returns = _utils._prepare_returns(returns, rf).resample(resolution).sum()
#     506     downside = abs(returns[returns < 0].sum())
#     507     return returns.sum() / downside
#
# File d:\Miniconda\envs\quant-dev\lib\site-packages\pandas\core\frame.py:10994, in DataFrame.resample(self, rule, axis, closed, label, convention, kind, on, level, origin, offset, group_keys)
#   10979 @doc(NDFrame.resample, **_shared_doc_kwargs)
#   10980 def resample(
#   10981     self,
#    (...)
#   10992     group_keys: bool = False,
#   10993 ) -> Resampler:
# > 10994     return super().resample(
#   10995         rule=rule,
#   10996         axis=axis,
#   10997         closed=closed,
#   10998         label=label,
#   10999         convention=convention,
#   11000         kind=kind,
#   11001         on=on,
#   11002         level=level,
#   11003         origin=origin,
#   11004         offset=offset,
#   11005         group_keys=group_keys,
#   11006     )
#
# File d:\Miniconda\envs\quant-dev\lib\site-packages\pandas\core\generic.py:8888, in NDFrame.resample(self, rule, axis, closed, label, convention, kind, on, level, origin, offset, group_keys)
#    8885 from pandas.core.resample import get_resampler
#    8887 axis = self._get_axis_number(axis)
# -> 8888 return get_resampler(
#    8889     cast("Series | DataFrame", self),
#    8890     freq=rule,
#    8891     label=label,
#    8892     closed=closed,
#    8893     axis=axis,
#    8894     kind=kind,
#    8895     convention=convention,
#    8896     key=on,
#    8897     level=level,
#    8898     origin=origin,
#    8899     offset=offset,
#    8900     group_keys=group_keys,
#    8901 )
#
# File d:\Miniconda\envs\quant-dev\lib\site-packages\pandas\core\resample.py:1522, in get_resampler(obj, kind, **kwds)
#    1518 def get_resampler(obj: Series | DataFrame, kind=None, **kwds) -> Resampler:
#    1519     """
#    1520     Create a TimeGrouper and return our resampler.
#    1521     """
# -> 1522     tg = TimeGrouper(**kwds)
#    1523     return tg._get_resampler(obj, kind=kind)
#
# File d:\Miniconda\envs\quant-dev\lib\site-packages\pandas\core\resample.py:1599, in TimeGrouper.__init__(self, freq, closed, label, how, axis, fill_method, limit, kind, convention, origin, offset, group_keys, **kwargs)
#    1596 if convention not in {None, "start", "end", "e", "s"}:
#    1597     raise ValueError(f"Unsupported value {convention} for `convention`")
# -> 1599 freq = to_offset(freq)
#    1601 end_types = {"M", "A", "Q", "BM", "BA", "BQ", "W"}
#    1602 rule = freq.rule_code
#
# File d:\Miniconda\envs\quant-dev\lib\site-packages\pandas\_libs\tslibs\offsets.pyx:4102, in pandas._libs.tslibs.offsets.to_offset()
#
# File d:\Miniconda\envs\quant-dev\lib\site-packages\pandas\_libs\tslibs\offsets.pyx:4198, in pandas._libs.tslibs.offsets.to_offset()
#
# ValueError: Invalid frequency: ME
